# %% [markdown]
# [Open REUTERS notebook in Colab](https://colab.research.google.com/github/El-leandr0/deeplearning_with_python/blob/main/REUTERS.ipynb):

# %% [markdown]
# [![Open In Colabb](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/El-leandr0/deeplearning_with_python/blob/main/REUTERS.ipynb)

# %%
# hi
